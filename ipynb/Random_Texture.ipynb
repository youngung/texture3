# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from TX import upf

# %%
nsamp=1000
xs=np.zeros(nsamp)
for i in range(nsamp):
    xs[i]=np.random.random()
dump=hist(xs,density=True)

# %%
nsamp=8000
phi1=np.random.random(nsamp)*360
phi=np.arccos(np.random.random(nsamp))*180./np.pi
phi2=np.random.random(nsamp)*360 
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(phi1,phi,phi2,marker='.',s=1)

# %%
wgts=phi1.copy()
wgts[:]=1.
grains=np.array([phi1,phi,phi2,wgts]).T
mypf=upf.polefigure(grains=grains,csym='cubic')
fig=mypf.pf_new(mode='dot',s=0.01,marker='x',c='r')
fig=mypf.pf_new()
# Out:
# Elapsed time for calling cells_pf:           1 [sec]
