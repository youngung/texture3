# %%
# %matplotlib inline
from TX import upf, cmb
import numpy as np
import matplotlib.pyplot as plt
import time
# %load_ext autoreload
# %autoreload 1

# %% [markdown]
# ## Hexgonal

# %%
filename='/Users/youngung/repo/vpsc_plus_e/examples/ex15_FLD/magnesium/az31/LS_AZ31_1.3mm.tex'
mypf=upf.polefigure(filename=filename,
    #grains=grs_iso,
    csym='hexag',cdim=[1,1,1.6235],cang=[90,90,120])
t0=time.time()
mypf.pf_new(poles=[[0,0,0,2],[1,0,-1,0],[1,0,-1,1]],
            n_rim=2,lev_opt=0,#lev_norm_log=True,
            nlev=6,cmap='jet',dth=10,dph=10,mn=0.6,ismooth=3)
print('pf_new time:', time.time()-t0)
#plt.tight_layout()
plt.gcf().savefig('temp_pf.pdf',bbox_inches='tight')
plt.gcf().savefig('temp_pf.png',bbox_inches='tight',transparent=True)
# Out:
# Elapsed time for calling cells_pf:         480 [ ms]
# Original x.shape: (37, 10)
# Original y.shape: (37, 10)
# Original nArray.shape: (3, 37, 10)
#
# Elapsed time for smoothing:         936 [ us]
#
# New x.shape: (111, 30)
# New y.shape: (111, 30)
# New nArray.shape: (3, 111, 30)
#
# Elapsed time for step 2:           2 [ ms](-1) nArray.shape: (3, 111, 30)
# xs.shape: (1662,)
# ys.shape: (1662,)
# np.log(xs.shape[0]): 7.415776975415394
#
# Elapsed time for step 3:           3 [ ms]
# Elapsed time for step 4:           5 [ ms]
# Elapsed time for step 2:           1 [ ms](-1) nArray.shape: (3, 111, 30)
# xs.shape: (1945,)
# ys.shape: (1945,)
# np.log(xs.shape[0]): 7.573017256052546
#
# Elapsed time for step 3:           3 [ ms]
# Elapsed time for step 4:           4 [ ms]
# Elapsed time for step 2:           1 [ ms](-1) nArray.shape: (3, 111, 30)
# xs.shape: (1153,)
# ys.shape: (1153,)
# np.log(xs.shape[0]): 7.050122520269059
#
# Elapsed time for step 3:           2 [ ms]
# Elapsed time for step 4:           4 [ ms]pf_new time: 0.5081620216369629

# %% [markdown]
# ## Cubic

# %%
filename='/Users/youngung/repo/vpsc_plus_e/mat/bcc/alpha_fib_ngr01500_sigma015.cmb'
mypf=upf.polefigure(filename=filename,csym='cubic',cdim=[1,1,1.],cang=[90,90,90])

pole=[[0,0,1],[1,1,0],[1,1,1],[2,1,1]]

t0=time.time()
fig=mypf.pf_new(poles=pole,dth=10,dph=10,n_rim=1,cmap='jet',lev_opt=0,ismooth=3)
# Out:
# Elapsed time for calling cells_pf:         326 [ ms]
# Original x.shape: (37, 10)
# Original y.shape: (37, 10)
# Original nArray.shape: (4, 37, 10)
#
# Elapsed time for smoothing:           1 [ ms]
#
# New x.shape: (111, 30)
# New y.shape: (111, 30)
# New nArray.shape: (4, 111, 30)
#
# Elapsed time for step 2:           3 [ ms](-1) nArray.shape: (4, 111, 30)
# xs.shape: (1002,)
# ys.shape: (1002,)
# np.log(xs.shape[0]): 6.90975328164481
#
# Elapsed time for step 3:           4 [ ms]
# Elapsed time for step 4:           5 [ ms]
# Elapsed time for step 2:           2 [ ms](-1) nArray.shape: (4, 111, 30)
# xs.shape: (663,)
# ys.shape: (663,)
# np.log(xs.shape[0]): 6.4967749901858625
#
# Elapsed time for step 3:           3 [ ms]
# Elapsed time for step 4:           5 [ ms]
# Elapsed time for step 2:           2 [ ms](-1) nArray.shape: (4, 111, 30)
# xs.shape: (1252,)
# ys.shape: (1252,)
# np.log(xs.shape[0]): 7.132497551660044
#
# Elapsed time for step 3:           3 [ ms]
# Elapsed time for step 4:           5 [ ms]
# Elapsed time for step 2:           2 [ ms](-1) nArray.shape: (4, 111, 30)
# xs.shape: (54,)
# ys.shape: (54,)
# np.log(xs.shape[0]): 3.9889840465642745
#
# Elapsed time for step 3:           3 [ ms]
# Elapsed time for step 4:           6 [ ms]
